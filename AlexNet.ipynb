# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from IPython.display import HTML
from tensorflow.keras.applications.vgg19 import VGG19
import numpy as np
import pandas as pd
import PIL.Image as Image
import os
import tensorflow_hub as hub
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from glob import glob
from keras.layers import Activation, BatchNormalization, Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from sklearn.utils.multiclass import unique_labels
from tensorflow.keras.applications.vgg16 import VGG16
from keras.applications import xception
from keras.applications.densenet import DenseNet121
from keras.applications.inception_v3 import InceptionV3

# %%
from zipfile import ZipFile

with ZipFile('/content/drive/MyDrive/Colab Notebooks/Breast Cancer/BUID Dataset.zip', 'r') as zipObj:

     zipObj.extractall('BreastCancer')

# %%
pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: split-folders in /usr/local/lib/python3.7/dist-packages (0.5.1)

# %%
import splitfolders
input_folder = '/content/BreastCancer/BUID/'

# %%
splitfolders.ratio(input_folder, output="dataset3",
                   seed=123, ratio=(.8, .1, .1), 
                   group_prefix=None)
# Out:
# Copying files: 780 files [00:00, 1638.58 files/s]

# %%
BATCH_SIZE = 64
IMAGE_SIZE = 224
CHANNELS=3
EPOCHS = 50

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
'/content/dataset3/train',
image_size= (IMAGE_SIZE, IMAGE_SIZE), batch_size= BATCH_SIZE)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
'/content/dataset3/test',
image_size= (IMAGE_SIZE, IMAGE_SIZE), batch_size= BATCH_SIZE)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
'/content/dataset3/val',
image_size= (IMAGE_SIZE, IMAGE_SIZE), batch_size= BATCH_SIZE)
# Out:
# Found 623 files belonging to 3 classes.
# Found 80 files belonging to 3 classes.
# Found 77 files belonging to 3 classes.

# %%
train_dataset = tf.keras.preprocessing.image_dataset_from_directory('/content/dataset3/train')

class_names= train_dataset.class_names
class_names
# Out:
# Found 623 files belonging to 3 classes.
# ['benign', 'malignant', 'normal']

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
training_ds = train_ds.map(
lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten,\
 Conv2D, MaxPooling2D,BatchNormalization,LayerNormalization

model = Sequential()

model.add(Conv2D(filters=96, input_shape=(224,224,3), kernel_size=(11,11),\
 strides=(4,4), padding='valid'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
model.add(BatchNormalization())


model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='valid'))
model.add(BatchNormalization())


model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())


model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())


model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='valid'))
model.add(BatchNormalization())


model.add(Flatten())


model.add(Dense(4096, input_shape=(224*224*3,)))
model.add(Activation('relu'))


model.add(Dropout(0.4))
model.add(BatchNormalization())


model.add(Dense(4096))
model.add(Activation('relu'))

model.add(Dropout(0.4))
model.add(BatchNormalization())
model.add(Dense(1000))

model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 54, 54, 96)        34944
#
#  activation (Activation)     (None, 54, 54, 96)        0
#
#  max_pooling2d (MaxPooling2D  (None, 27, 27, 96)       0
#  )
#
#  batch_normalization (BatchN  (None, 27, 27, 96)       384
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 27, 27, 256)       614656
#
#  activation_1 (Activation)   (None, 27, 27, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 13, 13, 256)      1024
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 384)       885120
#
#  activation_2 (Activation)   (None, 13, 13, 384)       0
#
#  batch_normalization_2 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 384)       1327488
#
#  activation_3 (Activation)   (None, 13, 13, 384)       0
#
#  batch_normalization_3 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 256)       884992
#
#  activation_4 (Activation)   (None, 13, 13, 256)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 4096)              37752832
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  batch_normalization_5 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  batch_normalization_6 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  dense_2 (Dense)             (None, 1000)              4097000
#
#  activation_7 (Activation)   (None, 1000)              0
#
# =================================================================
# Total params: 62,416,616
# Trainable params: 62,397,480
# Non-trainable params: 19,136
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
import time
start = time.time()
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=EPOCHS,
)
print("Total time: ", time.time() - start, "seconds")
# Out:
# Epoch 1/50
# 10/10 [==============================] - 21s 411ms/step - loss: 5.8404 - accuracy: 0.4639 - val_loss: 18804.1152 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 10/10 [==============================] - 4s 166ms/step - loss: 3.1409 - accuracy: 0.6051 - val_loss: 14369.5117 - val_accuracy: 0.5584
# Epoch 3/50
# 10/10 [==============================] - 4s 161ms/step - loss: 1.7521 - accuracy: 0.7368 - val_loss: 4257.9395 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 10/10 [==============================] - 4s 161ms/step - loss: 1.1977 - accuracy: 0.7608 - val_loss: 1740.0824 - val_accuracy: 0.5584
# Epoch 5/50
# 10/10 [==============================] - 4s 159ms/step - loss: 0.7593 - accuracy: 0.7913 - val_loss: 799.9901 - val_accuracy: 0.5584
# Epoch 6/50
# 10/10 [==============================] - 4s 161ms/step - loss: 0.5975 - accuracy: 0.8122 - val_loss: 377.6324 - val_accuracy: 0.5325
# Epoch 7/50
# 10/10 [==============================] - 4s 159ms/step - loss: 0.4984 - accuracy: 0.8283 - val_loss: 163.2018 - val_accuracy: 0.5584
# Epoch 8/50
# 10/10 [==============================] - 5s 165ms/step - loss: 0.5085 - accuracy: 0.8620 - val_loss: 86.6045 - val_accuracy: 0.5584
# Epoch 9/50
# 10/10 [==============================] - 4s 158ms/step - loss: 0.4354 - accuracy: 0.8604 - val_loss: 57.2373 - val_accuracy: 0.5844
# Epoch 10/50
# 10/10 [==============================] - 6s 179ms/step - loss: 0.3595 - accuracy: 0.8812 - val_loss: 68.8784 - val_accuracy: 0.5584
# Epoch 11/50
# 10/10 [==============================] - 4s 160ms/step - loss: 0.2743 - accuracy: 0.9005 - val_loss: 27.2531 - val_accuracy: 0.6104
# Epoch 12/50
# 10/10 [==============================] - 4s 162ms/step - loss: 0.2948 - accuracy: 0.9053 - val_loss: 31.0222 - val_accuracy: 0.5455
# Epoch 13/50
# 10/10 [==============================] - 4s 161ms/step - loss: 0.2583 - accuracy: 0.9053 - val_loss: 68.2830 - val_accuracy: 0.5584
# Epoch 14/50
# 10/10 [==============================] - 4s 161ms/step - loss: 0.2971 - accuracy: 0.9165 - val_loss: 37.7092 - val_accuracy: 0.5844
# Epoch 15/50
# 10/10 [==============================] - 4s 166ms/step - loss: 0.2994 - accuracy: 0.9294 - val_loss: 35.4626 - val_accuracy: 0.5844
# Epoch 16/50
# 10/10 [==============================] - 4s 163ms/step - loss: 0.2508 - accuracy: 0.9197 - val_loss: 26.7060 - val_accuracy: 0.5844
# Epoch 17/50
# 10/10 [==============================] - 4s 161ms/step - loss: 0.2901 - accuracy: 0.9053 - val_loss: 22.9757 - val_accuracy: 0.5714
# Epoch 18/50
# 10/10 [==============================] - 4s 164ms/step - loss: 0.3160 - accuracy: 0.9069 - val_loss: 3.6245 - val_accuracy: 0.6753
# Epoch 19/50
# 10/10 [==============================] - 4s 161ms/step - loss: 0.2753 - accuracy: 0.9165 - val_loss: 5.0161 - val_accuracy: 0.6104
# Epoch 20/50
# 10/10 [==============================] - 4s 159ms/step - loss: 0.1794 - accuracy: 0.9390 - val_loss: 4.5742 - val_accuracy: 0.6364
# Epoch 21/50
# 10/10 [==============================] - 4s 164ms/step - loss: 0.1359 - accuracy: 0.9518 - val_loss: 3.0756 - val_accuracy: 0.7013
# Epoch 22/50
# 10/10 [==============================] - 4s 163ms/step - loss: 0.1637 - accuracy: 0.9583 - val_loss: 4.6714 - val_accuracy: 0.6753
# Epoch 23/50
# 10/10 [==============================] - 4s 163ms/step - loss: 0.1022 - accuracy: 0.9711 - val_loss: 7.8359 - val_accuracy: 0.6104
# Epoch 24/50
# 10/10 [==============================] - 4s 162ms/step - loss: 0.0878 - accuracy: 0.9695 - val_loss: 5.1388 - val_accuracy: 0.6753
# Epoch 25/50
# 10/10 [==============================] - 4s 164ms/step - loss: 0.1655 - accuracy: 0.9486 - val_loss: 11.1963 - val_accuracy: 0.5844
# Epoch 26/50
# 10/10 [==============================] - 4s 165ms/step - loss: 0.1889 - accuracy: 0.9535 - val_loss: 3.2820 - val_accuracy: 0.7143
# Epoch 27/50
# 10/10 [==============================] - 4s 162ms/step - loss: 0.3217 - accuracy: 0.9278 - val_loss: 6.2179 - val_accuracy: 0.6494
# Epoch 28/50
# 10/10 [==============================] - 4s 162ms/step - loss: 0.1463 - accuracy: 0.9454 - val_loss: 4.5819 - val_accuracy: 0.7273
# Epoch 29/50
# 10/10 [==============================] - 4s 164ms/step - loss: 0.1056 - accuracy: 0.9599 - val_loss: 6.8657 - val_accuracy: 0.7013
# Epoch 30/50
# 10/10 [==============================] - 4s 166ms/step - loss: 0.1260 - accuracy: 0.9599 - val_loss: 5.2223 - val_accuracy: 0.6234
# Epoch 31/50
# 10/10 [==============================] - 4s 163ms/step - loss: 0.1203 - accuracy: 0.9551 - val_loss: 5.0668 - val_accuracy: 0.6753
# Epoch 32/50
# 10/10 [==============================] - 4s 166ms/step - loss: 0.1458 - accuracy: 0.9551 - val_loss: 3.5311 - val_accuracy: 0.7273
# Epoch 33/50
# 10/10 [==============================] - 4s 162ms/step - loss: 0.0950 - accuracy: 0.9759 - val_loss: 2.5659 - val_accuracy: 0.7143
# Epoch 34/50
# 10/10 [==============================] - 4s 164ms/step - loss: 0.0811 - accuracy: 0.9759 - val_loss: 3.2311 - val_accuracy: 0.7403
# Epoch 35/50
# 10/10 [==============================] - 4s 165ms/step - loss: 0.1029 - accuracy: 0.9695 - val_loss: 2.0359 - val_accuracy: 0.7013
# Epoch 36/50
# 10/10 [==============================] - 4s 163ms/step - loss: 0.1090 - accuracy: 0.9679 - val_loss: 2.3537 - val_accuracy: 0.7273
# Epoch 37/50
# 10/10 [==============================] - 4s 162ms/step - loss: 0.0966 - accuracy: 0.9695 - val_loss: 3.8333 - val_accuracy: 0.6753
# Epoch 38/50
# 10/10 [==============================] - 4s 164ms/step - loss: 0.1029 - accuracy: 0.9631 - val_loss: 4.2954 - val_accuracy: 0.6364
# Epoch 39/50
# 10/10 [==============================] - 4s 162ms/step - loss: 0.0652 - accuracy: 0.9759 - val_loss: 1.9600 - val_accuracy: 0.7143
# Epoch 40/50
# 10/10 [==============================] - 5s 189ms/step - loss: 0.1071 - accuracy: 0.9679 - val_loss: 1.5872 - val_accuracy: 0.7662
# Epoch 41/50
# 10/10 [==============================] - 4s 168ms/step - loss: 0.1185 - accuracy: 0.9663 - val_loss: 2.4110 - val_accuracy: 0.7143
# Epoch 42/50
# 10/10 [==============================] - 4s 163ms/step - loss: 0.1282 - accuracy: 0.9599 - val_loss: 3.6097 - val_accuracy: 0.7143
# Epoch 43/50
# 10/10 [==============================] - 4s 161ms/step - loss: 0.1025 - accuracy: 0.9695 - val_loss: 4.1156 - val_accuracy: 0.6494
# Epoch 44/50
# 10/10 [==============================] - 4s 161ms/step - loss: 0.1119 - accuracy: 0.9679 - val_loss: 5.4054 - val_accuracy: 0.5974
# Epoch 45/50
# 10/10 [==============================] - 4s 166ms/step - loss: 0.0827 - accuracy: 0.9711 - val_loss: 2.1647 - val_accuracy: 0.7143
# Epoch 46/50
# 10/10 [==============================] - 4s 165ms/step - loss: 0.0606 - accuracy: 0.9823 - val_loss: 2.0990 - val_accuracy: 0.7532
# Epoch 47/50
# 10/10 [==============================] - 4s 166ms/step - loss: 0.0497 - accuracy: 0.9791 - val_loss: 1.7835 - val_accuracy: 0.7273
# Epoch 48/50
# 10/10 [==============================] - 4s 163ms/step - loss: 0.0494 - accuracy: 0.9856 - val_loss: 1.9519 - val_accuracy: 0.7403
# Epoch 49/50
# 10/10 [==============================] - 4s 165ms/step - loss: 0.0436 - accuracy: 0.9807 - val_loss: 2.5561 - val_accuracy: 0.7403
# Epoch 50/50
# 10/10 [==============================] - 4s 168ms/step - loss: 0.0737 - accuracy: 0.9775 - val_loss: 2.6480 - val_accuracy: 0.7403
# Total time:  257.42147731781006 seconds

# %%
scores = model.evaluate(test_ds)
# Out:
# 2/2 [==============================] - 1s 353ms/step - loss: 1.8162 - accuracy: 0.7875
